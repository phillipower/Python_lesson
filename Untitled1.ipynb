# %%
gff_files_and_source_urls = {"S_aureus.gff.gz" : "ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/013/425/GCF_000013425.1_ASM1342v1/GCF_000013425.1_ASM1342v1_genomic.gff.gz",
                           "S_typhimurium.gff.gz" : "ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/195/995/GCF_000195995.1_ASM19599v1/GCF_000195995.1_ASM19599v1_genomic.gff.gz",
                           "E_coli.gff.gz":"ftp://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Escherichia_coli/reference/GCF_000005845.2_ASM584v2/GCF_000005845.2_ASM584v2_genomic.gff.gz"}

# %%
for file_name, url in gff_files_and_source_urls.items():
    print(file_name, url)
# Out:
# S_aureus.gff.gz ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/013/425/GCF_000013425.1_ASM1342v1/GCF_000013425.1_ASM1342v1_genomic.gff.gz
# S_typhimurium.gff.gz ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/195/995/GCF_000195995.1_ASM19599v1/GCF_000195995.1_ASM19599v1_genomic.gff.gz
# E_coli.gff.gz ftp://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Escherichia_coli/reference/GCF_000005845.2_ASM584v2/GCF_000005845.2_ASM584v2_genomic.gff.gz

# %%
import urllib.request
# dodaje bibliotece alias w postaci skrotu pd- wg konwencji dokumentacji - dobra praktyka
import pandas as pd
#urllib.request.urlretrieve(source_url, gff_file)

# %%
source_url1 = "ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/013/425/GCF_000013425.1_ASM1342v1/GCF_000013425.1_ASM1342v1_genomic.gff.gz"
gff_file1 = "S_aureus.gff.gz"

# %%
source_url2 = "ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/195/995/GCF_000195995.1_ASM19599v1/GCF_000195995.1_ASM19599v1_genomic.gff.gz"
gff_file2 = "S_typhimurium.gff.gz"

# %%
source_url3 = "ftp://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Escherichia_coli/reference/GCF_000005845.2_ASM584v2/GCF_000005845.2_ASM584v2_genomic.gff.gz"
gff_file3 = "E_coli.gff.gz"

# %%
urllib.request.urlretrieve(source_url1, gff_file1)
# Out:
# ('S_aureus.gff.gz', <email.message.Message at 0x262d37a3f48>)

# %%
urllib.request.urlretrieve(source_url2, gff_file2)
# Out:
# ('S_typhimurium.gff.gz', <email.message.Message at 0x262d37b1f08>)

# %%
urllib.request.urlretrieve(source_url3, gff_file3)
# Out:
# ('E_coli.gff.gz', <email.message.Message at 0x262d37bb548>)

# %%
gff_data1 = pd.read_csv(gff_file1, sep="\t", comment="#", names=["seqid", "source","type","start","end","score","strand","phase","attributes"])

# %%
gff_data2 = pd.read_csv(gff_file2, sep="\t", comment="#", names=["seqid", "source","type","start","end","score","strand","phase","attributes"])

# %%
gff_data3 = pd.read_csv(gff_file3, sep="\t", comment="#", names=["seqid", "source","type","start","end","score","strand","phase","attributes"])

# %%
gff_data1
# Out:
#             seqid  source    type    start      end score strand phase  \
# 0     NC_007795.1  RefSeq  region        1  2821361     .      +     .
# 1     NC_007795.1  RefSeq    gene      517     1878     .      +     .
# 2     NC_007795.1  RefSeq     CDS      517     1878     .      +     0
# 3     NC_007795.1  RefSeq    gene     2156     3289     .      +     .
# 4     NC_007795.1  RefSeq     CDS     2156     3289     .      +     0
# ...           ...     ...     ...      ...      ...   ...    ...   ...
# 5789  NC_007795.1  RefSeq     CDS  2819018  2820397     .      -     0
# 5790  NC_007795.1  RefSeq    gene  2820536  2820889     .      -     .
# 5791  NC_007795.1  RefSeq     CDS  2820536  2820889     .      -     0
# 5792  NC_007795.1  RefSeq    gene  2821010  2821147     .      -     .
# 5793  NC_007795.1  RefSeq     CDS  2821010  2821147     .      -     0
#
#                                              attributes
# 0     ID=id0;Dbxref=taxon:93061;Is_circular=true;Nam...
# ...

# %%
gff_data2
# Out:
#              seqid  source             type   start      end score strand  \
# 0      NC_003198.1  RefSeq           region       1  4809037     .      +
# 1      NC_003198.1  RefSeq             gene     190      255     .      +
# 2      NC_003198.1  RefSeq              CDS     190      255     .      +
# 3      NC_003198.1  RefSeq             gene     337     2799     .      +
# 4      NC_003198.1  RefSeq              CDS     337     2799     .      +
# ...            ...     ...              ...     ...      ...   ...    ...
# 11942  NC_003385.1  RefSeq  inverted_repeat  106230   106250     .      -
# 11943  NC_003385.1  RefSeq  inverted_repeat  106270   106290     .      -
# 11944  NC_003385.1  RefSeq  inverted_repeat  106317   106337     .      -
# 11945  NC_003385.1  RefSeq             gene  106342   106545     .      -
# 11946  NC_003385.1  RefSeq              CDS  106342   106545     .      -
#
#       phase                                         attributes
# ...

# %%
gff_data3
# Out:
#              seqid  source    type    start      end score strand phase  \
# 0      NC_000913.3  RefSeq  region        1  4641652     .      +     .
# 1      NC_000913.3  RefSeq    gene      190      255     .      +     .
# 2      NC_000913.3  RefSeq     CDS      190      255     .      +     0
# 3      NC_000913.3  RefSeq    gene      337     2799     .      +     .
# 4      NC_000913.3  RefSeq     CDS      337     2799     .      +     0
# ...            ...     ...     ...      ...      ...   ...    ...   ...
# 10116  NC_000913.3  RefSeq     CDS  4639590  4640306     .      -     0
# 10117  NC_000913.3  RefSeq    gene  4640402  4640542     .      +     .
# 10118  NC_000913.3  RefSeq     CDS  4640402  4640542     .      +     0
# 10119  NC_000913.3  RefSeq    gene  4640942  4641628     .      +     .
# 10120  NC_000913.3  RefSeq     CDS  4640942  4641628     .      +     0
#
#                                               attributes
# ...

# %%
gff_genes1 = gff_data1[gff_data1["type"] =="gene"]

# %%
gff_genes2 = gff_data2[gff_data2["type"] =="gene"]

# %%
gff_genes3 = gff_data3[gff_data3["type"] =="gene"]

# %%
gff_genes1
# Out:
#             seqid  source  type    start      end score strand phase  \
# 1     NC_007795.1  RefSeq  gene      517     1878     .      +     .
# 3     NC_007795.1  RefSeq  gene     2156     3289     .      +     .
# 5     NC_007795.1  RefSeq  gene     3670     3915     .      +     .
# 7     NC_007795.1  RefSeq  gene     3912     5024     .      +     .
# 9     NC_007795.1  RefSeq  gene     5034     6968     .      +     .
# ...           ...     ...   ...      ...      ...   ...    ...   ...
# 5784  NC_007795.1  RefSeq  gene  2816355  2817074     .      -     .
# 5786  NC_007795.1  RefSeq  gene  2817074  2818951     .      -     .
# 5788  NC_007795.1  RefSeq  gene  2819018  2820397     .      -     .
# 5790  NC_007795.1  RefSeq  gene  2820536  2820889     .      -     .
# 5792  NC_007795.1  RefSeq  gene  2821010  2821147     .      -     .
#
#                                              attributes
# 1     ID=gene0;Dbxref=GeneID:3919798;Name=dnaA;gbkey...
# ...

# %%
gff_genes1["length"] = gff_genes1["end"] - gff_genes1["start"] + 1
# Out:
# C:\Users\saman\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
gff_genes1["length"]
# Out:
# 1       1362
# 3       1134
# 5        246
# 7       1113
# 9       1935
#         ...
# 5784     720
# 5786    1878
# 5788    1380
# 5790     354
# 5792     138
# Name: length, Length: 2842, dtype: int64

# %%
gff_genes2["length"] = gff_genes2["end"] - gff_genes2["start"] + 1
# Out:
# C:\Users\saman\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
gff_genes3["length"] = gff_genes3["end"] - gff_genes3["start"] + 1
# Out:
# C:\Users\saman\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
